# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import OrdinalEncoder
from sklearn.decomposition import KernelPCA
from sklearn.pipeline import make_pipeline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/regression/Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
prep_pipeline = make_pipeline(OrdinalEncoder(), KernelPCA(n_components=2),)

# %%
features = prep_pipeline.fit_transform(df.drop(columns=['CustomerID']))

# %%
plt.figure(figsize=(20,10))
dendrogram(linkage(features, method='ward'))
plt.title('best number of cluster = 5')
plt.show()

# %%
X = df.drop(columns=['CustomerID'])
model = make_pipeline(
    prep_pipeline,
    AgglomerativeClustering(n_clusters=5)
)
groups = model.fit_predict(X)

# %%
X['groups'] = groups
X
# Out:
#       Genre  Age  Annual Income (k$)  Spending Score (1-100)  groups
# 0      Male   19                  15                      39       1
# 1      Male   21                  15                      81       3
# 2    Female   20                  16                       6       1
# 3    Female   23                  16                      77       3
# 4    Female   31                  17                      40       1
# ..      ...  ...                 ...                     ...     ...
# 195  Female   35                 120                      79       4
# 196  Female   45                 126                      28       2
# 197    Male   32                 126                      74       4
# 198    Male   32                 137                      18       2
# 199    Male   30                 137                      83       4
#
# [200 rows x 5 columns]

# %%
plt.figure(figsize=(14, 5))
plt.scatter(x= features[:,0], y = features[:,1], c= groups, s=100, cmap='rainbow', edgecolors='black', alpha=.6)
