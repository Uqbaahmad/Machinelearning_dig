# %%
import numpy as np
import pandas as pd
import seaborn as sns
from statsmodels.formula.api import ols

# %%
df = pd.read_csv('clean_automobile.csv')

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make  fuel-type  \
# 0             0          3              122.0  alfa-romero        1.0
# 1             1          3              122.0  alfa-romero        1.0
# 2             2          1              122.0  alfa-romero        1.0
# 3             3          2              164.0         audi        1.0
# 4             4          2              164.0         audi        1.0
# ..          ...        ...                ...          ...        ...
# 196         200         -1               95.0        volvo        1.0
# 197         201         -1               95.0        volvo        1.0
# 198         202         -1               95.0        volvo        1.0
# 199         203         -1               95.0        volvo        0.0
# 200         204         -1               95.0        volvo        1.0
#
#      aspiration  num-of-doors   body-style drive-wheels  engine-location  ...  \
# ...

# %%
df.corr()
# Out:
#                    Unnamed: 0  symboling  normalized-losses  fuel-type  \
# Unnamed: 0           1.000000  -0.161862      -2.410335e-01  -0.122076
# symboling           -0.161862   1.000000       4.662638e-01   0.196735
# normalized-losses   -0.241034   0.466264       1.000000e+00   0.101546
# fuel-type           -0.122076   0.196735       1.015463e-01   1.000000
# aspiration           0.082694  -0.054615      -6.910980e-03  -0.408228
# num-of-doors        -0.174339   0.672344       3.613676e-01   0.186681
# engine-location      0.050204   0.212339       9.412733e-17   0.040917
# wheel-base           0.125728  -0.535987      -5.666124e-02  -0.307237
# length               0.162374  -0.365404       1.942356e-02  -0.211187
# width                0.044613  -0.242423       8.680206e-02  -0.244356
# height               0.251376  -0.550160      -3.737370e-01  -0.281578
# curb-weight          0.065501  -0.233118       9.940425e-02  -0.221046
# ...

# %%
print(ols('price ~ horsepower', data= df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     378.5
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):           6.37e-48
# Time:                        19:36:39   Log-Likelihood:                -1982.7
# No. Observations:                 201   AIC:                             3969.
# Df Residuals:                     199   BIC:                             3976.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4597.5583    972.807     -4.726      0.000   -6515.891   -2679.226
# ...

# %%
print(ols('price ~ length', data= df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.477
# Model:                            OLS   Adj. R-squared:                  0.474
# Method:                 Least Squares   F-statistic:                     181.5
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):           8.02e-30
# Time:                        19:36:40   Log-Likelihood:                -2024.7
# No. Observations:                 201   AIC:                             4053.
# Df Residuals:                     199   BIC:                             4060.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6.438e+04   5774.126    -11.151      0.000   -7.58e+04    -5.3e+04
# ...

# %%
print(ols('price ~ bore', data= df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.295
# Model:                            OLS   Adj. R-squared:                  0.291
# Method:                 Least Squares   F-statistic:                     83.28
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):           8.05e-17
# Time:                        19:36:40   Log-Likelihood:                -2054.7
# No. Observations:                 201   AIC:                             4113.
# Df Residuals:                     199   BIC:                             4120.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -4.042e+04   5895.868     -6.856      0.000   -5.21e+04   -2.88e+04
# ...

# %%
print(ols('price ~ width', data= df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.562
# Method:                 Least Squares   F-statistic:                     257.8
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):           9.20e-38
# Time:                        19:36:41   Log-Likelihood:                -2006.3
# No. Observations:                 201   AIC:                             4017.
# Df Residuals:                     199   BIC:                             4023.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -1.74e+05   1.17e+04    -14.917      0.000   -1.97e+05   -1.51e+05
# ...

# %%
print(ols('price ~ aspiration', data= df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     6.631
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):             0.0107
# Time:                        19:36:42   Log-Likelihood:                -2086.5
# No. Observations:                 201   AIC:                             4177.
# Df Residuals:                     199   BIC:                             4184.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.254e+04    610.148     20.556      0.000    1.13e+04    1.37e+04
# ...

# %%
print(ols('price ~ stroke' ,data=df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.356
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):              0.246
# Time:                        19:36:43   Log-Likelihood:                -2089.1
# No. Observations:                 201   AIC:                             4182.
# Df Residuals:                     199   BIC:                             4189.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6469.7186   5812.718      1.113      0.267   -4992.708    1.79e+04
# ...

# %%
print(ols('price ~ symboling' ,data=df).fit().summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.360
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):              0.245
# Time:                        19:36:43   Log-Likelihood:                -2089.1
# No. Observations:                 201   AIC:                             4182.
# Df Residuals:                     199   BIC:                             4189.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.365e+04    674.662     20.226      0.000    1.23e+04     1.5e+04
# ...
